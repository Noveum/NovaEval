# %% [markdown]
# # Noveum Platform API Client - Complete Demo
#
# This notebook demonstrates all 28 methods available in the Noveum Platform API Client.
#
# ## API Methods Coverage:
# - **Trace Methods (7)**: Connection status, directory tree, ingest, query, get trace, get spans
# - **Dataset Methods (15)**: Create, list, get, update, delete, versions, version diff, items management
# - **Scorer Results Methods (6)**: Create, batch create, list, get, update, delete
#
# ## Prerequisites:
# - Set `NOVEUM_API_KEY` in your environment or `.env` file
# - Optionally set `NOVEUM_ORGANIZATION_ID`

# %% [markdown]
# ## Setup

# %%
# Cell 0: Import required libraries
import json
from pprint import pprint

from dotenv import load_dotenv

from novaeval.noveum_platform import NoveumClient

# Load environment variables
load_dotenv()

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
# Cell 1: Configuration Variables
# Customize these values as needed

PROJECT_NAME = "noveum-api-wrapper-demo"
ENVIRONMENT = "development"
DATASET_NAME = "Sample Traces Wrapper Demo 8"
DATASET_SLUG = "reddit-traces-wrapper-demo-8"
DATASET_VERSION = "1.0.0"
SCORER_ID = "demo-quality-scorer"
ORGANIZATION_SLUG = "magic-api"  # Adjust if needed
NUM_TRACES = 10

print("Configuration:")
print(f"  Project: {PROJECT_NAME}")
print(f"  Environment: {ENVIRONMENT}")
print(f"  Dataset: {DATASET_NAME}")
print(f"  Dataset Slug: {DATASET_SLUG}")
print(f"  Version: {DATASET_VERSION}")
print(f"  Scorer ID: {SCORER_ID}")
print(f"  Number of traces: {NUM_TRACES}")
print(f"  Organization Slug: {ORGANIZATION_SLUG}")
# Out:
# Configuration:
#   Project: noveum-api-wrapper-demo
#   Environment: development
#   Dataset: Sample Traces Wrapper Demo 8
#   Dataset Slug: reddit-traces-wrapper-demo-8
#   Version: 1.0.0
#   Scorer ID: demo-quality-scorer
#   Number of traces: 10
#   Organization Slug: magic-api

# %%
# Cell 2: Load Test Data
print("Loading test data from sample_traces.json...")

with open("../test_data/sample_traces.json") as f:
    all_traces = json.load(f)

# Extract first NUM_TRACES traces
traces_sample = all_traces[:NUM_TRACES]

print(f"\n✓ Loaded {len(traces_sample)} traces for demonstration")
print("\nSample trace structure (first trace):")
print(f"  Trace ID: {traces_sample[0].get('trace_id', 'N/A')}")
print(f"  Span ID: {traces_sample[0].get('span_id', 'N/A')}")
print(f"  Name: {traces_sample[0].get('name', 'N/A')}")
print(f"  Project: {traces_sample[0].get('project', 'N/A')}")
print(f"  Environment: {traces_sample[0].get('environment', 'N/A')}")
print(f"  Status: {traces_sample[0].get('status', 'N/A')}")
# Out:
# Loading test data from sample_traces.json...
#
# ✓ Loaded 10 traces for demonstration
#
# Sample trace structure (first trace):
#   Trace ID: e5eebd9b-3f9e-463f-b8f3-96e20a1f771a
#   Span ID: N/A
#   Name: Sample Trace 1
#   Project: noveum-api-wrapper-demo
#   Environment: development
#   Status: ok

# %%
# Cell 3: Initialize Noveum Client
print("Initializing Noveum Platform API Client...")

client = NoveumClient(
    # api_key is read from NOVEUM_API_KEY environment variable
    # organization_id is read from NOVEUM_ORGANIZATION_ID or can be passed explicitly
)

print("✓ Client initialized successfully")
print(f"  Base URL: {client.base_url}")
print(f"  Organization ID: {client.organization_id or 'Not set (will use from API key)'}")
# Out:
# Initializing Noveum Platform API Client...
# ✓ Client initialized successfully
#   Base URL: https://noveum.ai
#   Organization ID: Not set (will use from API key)

# %% [markdown]
# ## Trace Methods (7 methods)
#
# Demonstrating all trace-related API methods.

# %%
# Cell 4: Method 1 - get_connection_status()
print("=" * 60)
print("METHOD 1: get_connection_status()")
print("=" * 60)
print("\nChecking API connection status...\n")

connection_status = client.get_connection_status()
pprint(connection_status)
# Out:
# ============================================================
# METHOD 1: get_connection_status()
# ============================================================
#
# Checking API connection status...
#
# {'connected': True,
#  'connection_source': 'environment_variables',
#  'has_telemetry_plugin': False,
#  'processing_time_ms': 6,
#  'success': True,
#  'tables_ready': True,
#  'timestamp': '2025-10-21T20:32:26.052Z'}

# %%
# Cell 5: Method 2 - get_directory_tree()
print("=" * 60)
print("METHOD 2: get_directory_tree()")
print("=" * 60)
print("\nFetching organization directory tree...\n")

directory_tree = client.get_directory_tree()
pprint(directory_tree)
# Out:
# ============================================================
# METHOD 2: get_directory_tree()
# ============================================================
#
# Fetching organization directory tree...
#
# {'organization': {'id': 'fjMGlSqUngxBRJiDJCCVu6rrYqpJ4Xqh',
#                   'slug': 'magic-api'},
#  'success': True,
#  'tree': [{'children': [{'children': [{'id': 'project:customer-support-bot:dev-aman',
#                                        'metadata': {'environment': 'dev-aman',
#                                                     'lastActivity': '2025-10-16 '
#                                                                     '15:58:03.927000000',
#                                                     'project': 'customer-support-bot',
#                                                     'traceCount': 47494},
#                                        'name': 'customer-support-bot',
#                                        'type': 'project'},
#                                       {'id': 'project:load_testing:dev-aman',
#                                        'metadata': {'environment': 'dev-aman',
#                                                     'lastActivity': '2025-10-16 '
#                                                                     '16:03:20.395000000',
#                                                     'project': 'load_testing',
#                                                     'traceCount': 41184},
#                                        'name': 'load_testing',
#                                        'type': 'project'},
#                                       {'id': 'project:test_aman_customer_support_agent:dev-aman',
#                                        'metadata': {'environment': 'dev-aman',
#                                                     'lastActivity': '2025-10-15 '
#                                                                     '08:07:25.837000000',
#                                                     'project': 'test_aman_customer_support_agent',
#                                                     'traceCount': 12},
#                                        'name': 'test_aman_customer_support_agent',
#                                        'type': 'project'},
#                                       {'id': 'project:customer_support_agent:dev-aman',
#                                        'metadata': {'environment': 'dev-aman',
#                                                     'lastActivity': '2025-10-15 '
#                                                                     '09:13:29.265000000',
#                                                     'project': 'customer_support_agent',
#                                                     'traceCount': 9},
#                                        'name': 'customer_support_agent',
#                                        'type': 'project'}],
#                          'id': 'env:dev-aman',
#                          'metadata': {'environment': 'dev-aman',
#                                       'lastActivity': '2025-10-16 '
#                                                       '16:03:20.395000000',
#                                       'traceCount': 88699},
#                          'name': 'dev-aman',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:novaeval-wealthink:dev-shivam',
#                                        'metadata': {'environment': 'dev-shivam',
#                                                     'lastActivity': '2025-10-16 '
#                                                                     '08:53:46.068000000',
#                                                     'project': 'novaeval-wealthink',
#                                                     'traceCount': 2341},
#                                        'name': 'novaeval-wealthink',
#                                        'type': 'project'},
#                                       {'id': 'project:novaevalw:dev-shivam',
#                                        'metadata': {'environment': 'dev-shivam',
#                                                     'lastActivity': '2025-10-07 '
#                                                                     '17:20:01.508000000',
#                                                     'project': 'novaevalw',
#                                                     'traceCount': 2193},
#                                        'name': 'novaevalw',
#                                        'type': 'project'},
#                                       {'id': 'project:novaeval:dev-shivam',
#                                        'metadata': {'environment': 'dev-shivam',
#                                                     'lastActivity': '2025-09-24 '
#                                                                     '13:03:01.905000000',
#                                                     'project': 'novaeval',
#                                                     'traceCount': 471},
#                                        'name': 'novaeval',
#                                        'type': 'project'}],
#                          'id': 'env:dev-shivam',
#                          'metadata': {'environment': 'dev-shivam',
#                                       'lastActivity': '2025-10-16 '
#                                                       '08:53:46.068000000',
#                                       'traceCount': 5005},
#                          'name': 'dev-shivam',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:novaeval-ai-agents-prod:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-02 '
#                                                                     '12:39:52.650000000',
#                                                     'project': 'novaeval-ai-agents-prod',
#                                                     'traceCount': 559},
#                                        'name': 'novaeval-ai-agents-prod',
#                                        'type': 'project'},
#                                       {'id': 'project:reddit-agent-system:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-09-22 '
#                                                                     '13:38:27.927000000',
#                                                     'project': 'reddit-agent-system',
#                                                     'traceCount': 301},
#                                        'name': 'reddit-agent-system',
#                                        'type': 'project'},
#                                       {'id': 'project:noveum-ai-agent-rag-websearch:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-16 '
#                                                                     '08:50:56.153000000',
#                                                     'project': 'noveum-ai-agent-rag-websearch',
#                                                     'traceCount': 300},
#                                        'name': 'noveum-ai-agent-rag-websearch',
#                                        'type': 'project'},
#                                       {'id': 'project:novaeval-ai-agents-updated:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-09-30 '
#                                                                     '12:56:35.824000000',
#                                                     'project': 'novaeval-ai-agents-updated',
#                                                     'traceCount': 240},
#                                        'name': 'novaeval-ai-agents-updated',
#                                        'type': 'project'},
#                                       {'id': 'project:novaeval-ai-agents-final:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-02 '
#                                                                     '12:33:49.295000000',
#                                                     'project': 'novaeval-ai-agents-final',
#                                                     'traceCount': 99},
#                                        'name': 'novaeval-ai-agents-final',
#                                        'type': 'project'},
#                                       {'id': 'project:noveum-support-bot:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-08 '
#                                                                     '12:53:28.953000000',
#                                                     'project': 'noveum-support-bot',
#                                                     'traceCount': 79},
#                                        'name': 'noveum-support-bot',
#                                        'type': 'project'},
#                                       {'id': 'project:novaeval-ai-agents-dataset:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-09-28 '
#                                                                     '11:37:41.722000000',
#                                                     'project': 'novaeval-ai-agents-dataset',
#                                                     'traceCount': 31},
#                                        'name': 'novaeval-ai-agents-dataset',
#                                        'type': 'project'},
#                                       {'id': 'project:customer-support-bot:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-15 '
#                                                                     '08:25:22.560000000',
#                                                     'project': 'customer-support-bot',
#                                                     'traceCount': 10},
#                                        'name': 'customer-support-bot',
#                                        'type': 'project'},
#                                       {'id': 'project:noveum-api-wrapper-demo:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '13:09:01.180000000',
#                                                     'project': 'noveum-api-wrapper-demo',
#                                                     'traceCount': 10},
#                                        'name': 'noveum-api-wrapper-demo',
#                                        'type': 'project'},
#                                       {'id': 'project:example-project:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-12 '
#                                                                     '19:32:18.475000000',
#                                                     'project': 'example-project',
#                                                     'traceCount': 5},
#                                        'name': 'example-project',
#                                        'type': 'project'},
#                                       {'id': 'project:flexible-tracing-demo:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-14 '
#                                                                     '07:48:14.878000000',
#                                                     'project': 'flexible-tracing-demo',
#                                                     'traceCount': 5},
#                                        'name': 'flexible-tracing-demo',
#                                        'type': 'project'},
#                                       {'id': 'project:test-tracing-demo:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-14 '
#                                                                     '16:42:35.623000000',
#                                                     'project': 'test-tracing-demo',
#                                                     'traceCount': 3},
#                                        'name': 'test-tracing-demo',
#                                        'type': 'project'},
#                                       {'id': 'project:agent-example:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-14 '
#                                                                     '07:47:57.256000000',
#                                                     'project': 'agent-example',
#                                                     'traceCount': 2},
#                                        'name': 'agent-example',
#                                        'type': 'project'},
#                                       {'id': 'project:notification-service:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'notification-service',
#                                                     'traceCount': 2},
#                                        'name': 'notification-service',
#                                        'type': 'project'},
#                                       {'id': 'project:ecommerce-api:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'ecommerce-api',
#                                                     'traceCount': 1},
#                                        'name': 'ecommerce-api',
#                                        'type': 'project'},
#                                       {'id': 'project:payment-gateway:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'payment-gateway',
#                                                     'traceCount': 1},
#                                        'name': 'payment-gateway',
#                                        'type': 'project'},
#                                       {'id': 'project:test-project:development',
#                                        'metadata': {'environment': 'development',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '07:00:00.000000000',
#                                                     'project': 'test-project',
#                                                     'traceCount': 1},
#                                        'name': 'test-project',
#                                        'type': 'project'}],
#                          'id': 'env:development',
#                          'metadata': {'environment': 'development',
#                                       'lastActivity': '2025-10-21 '
#                                                       '13:09:01.180000000',
#                                       'traceCount': 1649},
#                          'name': 'development',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:langchain-deep-research:dev-shashank',
#                                        'metadata': {'environment': 'dev-shashank',
#                                                     'lastActivity': '2025-10-14 '
#                                                                     '08:08:32.036000000',
#                                                     'project': 'langchain-deep-research',
#                                                     'traceCount': 212},
#                                        'name': 'langchain-deep-research',
#                                        'type': 'project'}],
#                          'id': 'env:dev-shashank',
#                          'metadata': {'environment': 'dev-shashank',
#                                       'lastActivity': '2025-10-14 '
#                                                       '08:08:32.036000000',
#                                       'traceCount': 212},
#                          'name': 'dev-shashank',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:novaevalw:dev-shivamm',
#                                        'metadata': {'environment': 'dev-shivamm',
#                                                     'lastActivity': '2025-10-15 '
#                                                                     '12:05:30.005000000',
#                                                     'project': 'novaevalw',
#                                                     'traceCount': 85},
#                                        'name': 'novaevalw',
#                                        'type': 'project'},
#                                       {'id': 'project:noveum-trace-langchain:dev-shivamm',
#                                        'metadata': {'environment': 'dev-shivamm',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '10:06:05.842000000',
#                                                     'project': 'noveum-trace-langchain',
#                                                     'traceCount': 35},
#                                        'name': 'noveum-trace-langchain',
#                                        'type': 'project'},
#                                       {'id': 'project:novaeval-shivam:dev-shivamm',
#                                        'metadata': {'environment': 'dev-shivamm',
#                                                     'lastActivity': '2025-09-21 '
#                                                                     '21:00:24.769000000',
#                                                     'project': 'novaeval-shivam',
#                                                     'traceCount': 8},
#                                        'name': 'novaeval-shivam',
#                                        'type': 'project'}],
#                          'id': 'env:dev-shivamm',
#                          'metadata': {'environment': 'dev-shivamm',
#                                       'lastActivity': '2025-10-21 '
#                                                       '10:06:05.842000000',
#                                       'traceCount': 128},
#                          'name': 'dev-shivamm',
#                          'type': 'environment'}],
#            'id': 'env-category:dev',
#            'metadata': {'lastActivity': '2025-10-21 13:09:01.180000000',
#                         'traceCount': 95693},
#            'name': 'dev',
#            'type': 'filter'},
#           {'children': [{'children': [{'id': 'project:uptime-project:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-16 '
#                                                                     '02:00:00.000000000',
#                                                     'project': 'uptime-project',
#                                                     'traceCount': 10232},
#                                        'name': 'uptime-project',
#                                        'type': 'project'},
#                                       {'id': 'project:openai-agents-integration-test:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-09 '
#                                                                     '07:46:43.185000000',
#                                                     'project': 'openai-agents-integration-test',
#                                                     'traceCount': 3},
#                                        'name': 'openai-agents-integration-test',
#                                        'type': 'project'},
#                                       {'id': 'project:my-ai-app:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-15 '
#                                                                     '06:17:22.194000000',
#                                                     'project': 'my-ai-app',
#                                                     'traceCount': 2},
#                                        'name': 'my-ai-app',
#                                        'type': 'project'},
#                                       {'id': 'project:notification-service:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'notification-service',
#                                                     'traceCount': 1},
#                                        'name': 'notification-service',
#                                        'type': 'project'},
#                                       {'id': 'project:payment-gateway:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'payment-gateway',
#                                                     'traceCount': 1},
#                                        'name': 'payment-gateway',
#                                        'type': 'project'},
#                                       {'id': 'project:user-service:production',
#                                        'metadata': {'environment': 'production',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'user-service',
#                                                     'traceCount': 1},
#                                        'name': 'user-service',
#                                        'type': 'project'}],
#                          'id': 'env:production',
#                          'metadata': {'environment': 'production',
#                                       'lastActivity': '2025-10-21 '
#                                                       '12:50:59.343000000',
#                                       'traceCount': 10240},
#                          'name': 'production',
#                          'type': 'environment'}],
#            'id': 'env-category:prod',
#            'metadata': {'lastActivity': '2025-10-21 12:50:59.343000000',
#                         'traceCount': 10240},
#            'name': 'prod',
#            'type': 'filter'},
#           {'children': [{'children': [{'id': 'project:noveum-trace-python:git-integ-test',
#                                        'metadata': {'environment': 'git-integ-test',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '03:08:44.529000000',
#                                                     'project': 'noveum-trace-python',
#                                                     'traceCount': 401},
#                                        'name': 'noveum-trace-python',
#                                        'type': 'project'}],
#                          'id': 'env:git-integ-test',
#                          'metadata': {'environment': 'git-integ-test',
#                                       'lastActivity': '2025-10-21 '
#                                                       '03:08:44.529000000',
#                                       'traceCount': 401},
#                          'name': 'git-integ-test',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:reddit-agent-test:test',
#                                        'metadata': {'environment': 'test',
#                                                     'lastActivity': '2025-09-21 '
#                                                                     '21:25:40.611000000',
#                                                     'project': 'reddit-agent-test',
#                                                     'traceCount': 1},
#                                        'name': 'reddit-agent-test',
#                                        'type': 'project'}],
#                          'id': 'env:test',
#                          'metadata': {'environment': 'test',
#                                       'lastActivity': '2025-09-21 '
#                                                       '21:25:40.611000000',
#                                       'traceCount': 1},
#                          'name': 'test',
#                          'type': 'environment'}],
#            'id': 'env-category:test',
#            'metadata': {'lastActivity': '2025-10-21 03:08:44.529000000',
#                         'traceCount': 402},
#            'name': 'test',
#            'type': 'filter'},
#           {'children': [{'children': [{'id': 'project:maintenance-health-check:github-actions',
#                                        'metadata': {'environment': 'github-actions',
#                                                     'lastActivity': '2025-10-19 '
#                                                                     '03:07:48.549000000',
#                                                     'project': 'maintenance-health-check',
#                                                     'traceCount': 4},
#                                        'name': 'maintenance-health-check',
#                                        'type': 'project'}],
#                          'id': 'env:github-actions',
#                          'metadata': {'environment': 'github-actions',
#                                       'lastActivity': '2025-10-19 '
#                                                       '03:07:48.549000000',
#                                       'traceCount': 4},
#                          'name': 'github-actions',
#                          'type': 'environment'},
#                         {'children': [{'id': 'project:payment-gateway:staging',
#                                        'metadata': {'environment': 'staging',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'payment-gateway',
#                                                     'traceCount': 2},
#                                        'name': 'payment-gateway',
#                                        'type': 'project'},
#                                       {'id': 'project:ecommerce-api:staging',
#                                        'metadata': {'environment': 'staging',
#                                                     'lastActivity': '2025-10-21 '
#                                                                     '12:50:59.343000000',
#                                                     'project': 'ecommerce-api',
#                                                     'traceCount': 1},
#                                        'name': 'ecommerce-api',
#                                        'type': 'project'}],
#                          'id': 'env:staging',
#                          'metadata': {'environment': 'staging',
#                                       'lastActivity': '2025-10-21 '
#                                                       '12:50:59.343000000',
#                                       'traceCount': 3},
#                          'name': 'staging',
#                          'type': 'environment'}],
#            'id': 'env-category:others',
#            'metadata': {'lastActivity': '2025-10-21 12:50:59.343000000',
#                         'traceCount': 7},
#            'name': 'others',
#            'type': 'filter'}]}

# %%
# Cell 6: Method 3 - ingest_trace()
print("=" * 60)
print("METHOD 3: ingest_trace()")
print("=" * 60)
print("\nIngesting a single trace...\n")

# Prepare the first trace for ingestion
single_trace = traces_sample[0].copy()

# Update project and environment to our demo values
single_trace["project"] = PROJECT_NAME
single_trace["environment"] = ENVIRONMENT
if "trace_attributes" in single_trace:
    single_trace["trace_attributes"]["noveum.project"] = PROJECT_NAME
    single_trace["trace_attributes"]["noveum.environment"] = ENVIRONMENT

ingest_result = client.ingest_trace(single_trace)
print(f"✓ Successfully ingested trace: {single_trace['trace_id']}")
pprint(ingest_result)
# Out:
# ============================================================
# METHOD 3: ingest_trace()
# ============================================================
#
# Ingesting a single trace...
#
# ✓ Successfully ingested trace: e5eebd9b-3f9e-463f-b8f3-96e20a1f771a
# {'job_id': '15300',
#  'message': 'Trace queued for batch processing',
#  'processing_time_ms': 2,
#  'success': True,
#  'timestamp': '2025-10-21T20:32:26.860Z',
#  'trace_id': 'e5eebd9b-3f9e-463f-b8f3-96e20a1f771a'}

# %%
# Cell 7: Method 4 - ingest_traces()
print("=" * 60)
print("METHOD 4: ingest_traces()")
print("=" * 60)
print("\nIngesting multiple traces in batch...\n")

# Prepare remaining traces for batch ingestion
batch_traces = []
for trace in traces_sample[1:]:
    trace_copy = trace.copy()
    trace_copy["project"] = PROJECT_NAME
    trace_copy["environment"] = ENVIRONMENT
    if "trace_attributes" in trace_copy:
        trace_copy["trace_attributes"]["noveum.project"] = PROJECT_NAME
        trace_copy["trace_attributes"]["noveum.environment"] = ENVIRONMENT
    batch_traces.append(trace_copy)

batch_result = client.ingest_traces(batch_traces)
print(f"✓ Successfully ingested {len(batch_traces)} traces")
pprint(batch_result)
# Out:
# ============================================================
# METHOD 4: ingest_traces()
# ============================================================
#
# Ingesting multiple traces in batch...
#
# ✓ Successfully ingested 9 traces
# {'job_id': '15301',
#  'message': 'Batch traces queued for processing',
#  'processing_time_ms': 4,
#  'queued_count': 9,
#  'success': True,
#  'timestamp': '2025-10-21T20:32:27.291Z'}

# %%
# Cell 8: Method 5 - query_traces()
print("=" * 60)
print("METHOD 5: query_traces()")
print("=" * 60)
print("\nQuerying traces with filters...\n")

# Query traces with various filters
query_result = client.query_traces(
    project=PROJECT_NAME,
    environment=ENVIRONMENT,
    size=20,
    sort="start_time:desc",
    include_spans=False
)

print("Query parameters:")
print(f"  Project: {PROJECT_NAME}")
print(f"  Environment: {ENVIRONMENT}")
print("  Size: 20")
print("  Sort: start_time:desc")
print("\nQuery results:")
pprint(query_result)

# Store trace IDs for later use
if "traces" in query_result and len(query_result["traces"]) > 0:
    sample_trace_id = query_result["traces"][0].get("trace_id")
    print(f"\n✓ Found {len(query_result.get('traces', []))} traces")
    print(f"  Sample trace ID for next demos: {sample_trace_id}")
else:
    sample_trace_id = traces_sample[0]["trace_id"]
    print(f"\n! No traces in query result, using original trace ID: {sample_trace_id}")
# Out:
# ============================================================
# METHOD 5: query_traces()
# ============================================================
#
# Querying traces with filters...
#
# Query parameters:
#   Project: noveum-api-wrapper-demo
#   Environment: development
#   Size: 20
#   Sort: start_time:desc
#
# Query results:
# {'pagination': {'has_more': False, 'limit': 20, 'offset': 0, 'total': 10},
#  'processing_time_ms': 96,
#  'success': True,
#  'timestamp': '2025-10-21T20:32:27.640Z',
#  'traces': [{'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 906,
#              'end_time': '2025-10-21 13:09:02.086000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 3',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 5,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 1063,
#              'end_time': '2025-10-21 13:09:02.243000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 4',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 5,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'd3df971e-4206-40ba-81b1-cfb0f456f22a',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 556,
#              'end_time': '2025-10-21 13:09:01.736000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 1',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 2,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'e5eebd9b-3f9e-463f-b8f3-96e20a1f771a',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 2339,
#              'end_time': '2025-10-21 13:09:03.519000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 8',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 3,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': '16f0a3e6-4b0b-4963-adcf-e430f100577f',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 3002,
#              'end_time': '2025-10-21 13:09:04.182000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 10',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 5,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'ce23f2a2-9ee8-410b-bdf2-dd1d585376c6',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 2950,
#              'end_time': '2025-10-21 13:09:04.130000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 7',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 1,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'fb6f5237-6f40-4a36-9bc3-ebad1bf8d4fd',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 532,
#              'end_time': '2025-10-21 13:09:01.712000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 5',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 5,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': '77828ea1-8a55-4dee-9df3-6ce914ebeaab',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 3654,
#              'end_time': '2025-10-21 13:09:04.834000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 6',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 3,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'e22ce493-b6d1-4b47-bc37-81ed92d7b300',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 2276,
#              'end_time': '2025-10-21 13:09:03.456000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 2',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 1,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'e4e5e9ec-32de-40dc-b89d-80aa636cb45c',
#              'updated_at': '2025-10-21 13:09:01.180000000'},
#             {'attributes': {},
#              'created_at': '2025-10-21 13:09:01.180000000',
#              'duration_ms': 2719,
#              'end_time': '2025-10-21 13:09:03.899000000',
#              'environment': 'development',
#              'error_count': 0,
#              'metadata': {'custom_attributes': {},
#                           'request_id': None,
#                           'session_id': None,
#                           'tags': {},
#                           'user_id': None},
#              'name': 'Sample Trace 9',
#              'project': 'noveum-api-wrapper-demo',
#              'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#              'span_count': 1,
#              'spans': [],
#              'start_time': '2025-10-21 13:09:01.180000000',
#              'status': 'ok',
#              'status_message': '',
#              'trace_id': 'f28a4558-ec88-46f4-b599-bdb866d6f163',
#              'updated_at': '2025-10-21 13:09:01.180000000'}]}
#
# ✓ Found 10 traces
#   Sample trace ID for next demos: 82f70a57-cdac-44ee-9d76-5c14daed1ac4

# %%
# Cell 9: Method 6 - get_trace()
print("=" * 60)
print("METHOD 6: get_trace()")
print("=" * 60)
print(f"\nFetching specific trace by ID: {sample_trace_id}\n")

trace_detail = client.get_trace(sample_trace_id)
pprint(trace_detail)
# Out:
# ============================================================
# METHOD 6: get_trace()
# ============================================================
#
# Fetching specific trace by ID: 82f70a57-cdac-44ee-9d76-5c14daed1ac4
#
# {'data': {'attributes': {},
#           'created_at': '2025-10-21 13:09:01.180000000',
#           'duration_ms': 906,
#           'end_time': '2025-10-21 13:09:02.086000000',
#           'environment': 'development',
#           'error_count': 0,
#           'metadata': {'custom_attributes': {},
#                        'request_id': None,
#                        'session_id': None,
#                        'tags': {},
#                        'user_id': None},
#           'name': 'Sample Trace 3',
#           'project': 'noveum-api-wrapper-demo',
#           'sdk': {'name': 'noveum-python', 'version': '0.5.3'},
#           'span_count': 5,
#           'spans': [{'attributes': {'operation.type': 'query',
#                                     'request.size': 9355,
#                                     'service.name': 'service-1',
#                                     'user.id': 'user-4989'},
#                      'duration_ms': 272,
#                      'end_time': '2025-10-21 13:09:01.452000000',
#                      'events': [],
#                      'links': [],
#                      'name': 'Sample Trace 3_span_1',
#                      'parent_span_id': '',
#                      'span_id': '472262fa-7dfa-48b1-89bd-d379b2c60e56',
#                      'start_time': '2025-10-21 13:09:01.180000000',
#                      'status': 'error',
#                      'status_message': '',
#                      'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#                     {'attributes': {'operation.type': 'mutation',
#                                     'request.size': 554,
#                                     'service.name': 'service-2',
#                                     'user.id': 'user-7296'},
#                      'duration_ms': 129,
#                      'end_time': '2025-10-21 13:09:01.490000000',
#                      'events': [],
#                      'links': [],
#                      'name': 'Sample Trace 3_span_2',
#                      'parent_span_id': '',
#                      'span_id': 'aa2f87e5-5f03-4e53-817f-16e9ae69a6a0',
#                      'start_time': '2025-10-21 13:09:01.361000000',
#                      'status': 'error',
#                      'status_message': '',
#                      'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#                     {'attributes': {'operation.type': 'mutation',
#                                     'request.size': 8890,
#                                     'service.name': 'service-3',
#                                     'user.id': 'user-5736'},
#                      'duration_ms': 190,
#                      'end_time': '2025-10-21 13:09:01.732000000',
#                      'events': [],
#                      'links': [],
#                      'name': 'Sample Trace 3_span_3',
#                      'parent_span_id': '',
#                      'span_id': '5e6b66fb-5315-4569-893e-0f1ff1dd5bd8',
#                      'start_time': '2025-10-21 13:09:01.542000000',
#                      'status': 'error',
#                      'status_message': '',
#                      'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#                     {'attributes': {'operation.type': 'subscription',
#                                     'request.size': 2483,
#                                     'service.name': 'service-4',
#                                     'user.id': 'user-9448'},
#                      'duration_ms': 114,
#                      'end_time': '2025-10-21 13:09:01.837000000',
#                      'events': [],
#                      'links': [],
#                      'name': 'Sample Trace 3_span_4',
#                      'parent_span_id': '',
#                      'span_id': '51446d03-13d4-45b6-a95a-c1dc36737acc',
#                      'start_time': '2025-10-21 13:09:01.723000000',
#                      'status': 'ok',
#                      'status_message': '',
#                      'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#                     {'attributes': {'operation.type': 'subscription',
#                                     'request.size': 2077,
#                                     'service.name': 'service-5',
#                                     'user.id': 'user-9171'},
#                      'duration_ms': 117,
#                      'end_time': '2025-10-21 13:09:02.021000000',
#                      'events': [],
#                      'links': [],
#                      'name': 'Sample Trace 3_span_5',
#                      'parent_span_id': '',
#                      'span_id': 'd13eef3f-0836-4b0c-8abf-5245a7d073d7',
#                      'start_time': '2025-10-21 13:09:01.904000000',
#                      'status': 'ok',
#                      'status_message': '',
#                      'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'}],
#           'start_time': '2025-10-21 13:09:01.180000000',
#           'status': 'ok',
#           'status_message': '',
#           'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4',
#           'updated_at': '2025-10-21 13:09:01.180000000'},
#  'success': True,
#  'timestamp': '2025-10-21T20:32:27.923Z'}

# %%
# Cell 10: Method 7 - get_trace_spans()
print("=" * 60)
print("METHOD 7: get_trace_spans()")
print("=" * 60)
print(f"\nFetching spans for trace: {sample_trace_id}\n")

trace_spans = client.get_trace_spans(sample_trace_id)
pprint(trace_spans)

if "spans" in trace_spans:
    print(f"\n✓ Found {len(trace_spans['spans'])} spans")
# Out:
# ============================================================
# METHOD 7: get_trace_spans()
# ============================================================
#
# Fetching spans for trace: 82f70a57-cdac-44ee-9d76-5c14daed1ac4
#
# {'spans': [{'attributes': {'operation.type': 'query',
#                            'request.size': 9355,
#                            'service.name': 'service-1',
#                            'user.id': 'user-4989'},
#             'duration_ms': 272,
#             'end_time': '2025-10-21 13:09:01.452000000',
#             'events': [],
#             'links': [],
#             'name': 'Sample Trace 3_span_1',
#             'parent_span_id': '',
#             'span_id': '472262fa-7dfa-48b1-89bd-d379b2c60e56',
#             'start_time': '2025-10-21 13:09:01.180000000',
#             'status': 'error',
#             'status_message': '',
#             'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#            {'attributes': {'operation.type': 'mutation',
#                            'request.size': 554,
#                            'service.name': 'service-2',
#                            'user.id': 'user-7296'},
#             'duration_ms': 129,
#             'end_time': '2025-10-21 13:09:01.490000000',
#             'events': [],
#             'links': [],
#             'name': 'Sample Trace 3_span_2',
#             'parent_span_id': '',
#             'span_id': 'aa2f87e5-5f03-4e53-817f-16e9ae69a6a0',
#             'start_time': '2025-10-21 13:09:01.361000000',
#             'status': 'error',
#             'status_message': '',
#             'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#            {'attributes': {'operation.type': 'mutation',
#                            'request.size': 8890,
#                            'service.name': 'service-3',
#                            'user.id': 'user-5736'},
#             'duration_ms': 190,
#             'end_time': '2025-10-21 13:09:01.732000000',
#             'events': [],
#             'links': [],
#             'name': 'Sample Trace 3_span_3',
#             'parent_span_id': '',
#             'span_id': '5e6b66fb-5315-4569-893e-0f1ff1dd5bd8',
#             'start_time': '2025-10-21 13:09:01.542000000',
#             'status': 'error',
#             'status_message': '',
#             'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#            {'attributes': {'operation.type': 'subscription',
#                            'request.size': 2483,
#                            'service.name': 'service-4',
#                            'user.id': 'user-9448'},
#             'duration_ms': 114,
#             'end_time': '2025-10-21 13:09:01.837000000',
#             'events': [],
#             'links': [],
#             'name': 'Sample Trace 3_span_4',
#             'parent_span_id': '',
#             'span_id': '51446d03-13d4-45b6-a95a-c1dc36737acc',
#             'start_time': '2025-10-21 13:09:01.723000000',
#             'status': 'ok',
#             'status_message': '',
#             'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'},
#            {'attributes': {'operation.type': 'subscription',
#                            'request.size': 2077,
#                            'service.name': 'service-5',
#                            'user.id': 'user-9171'},
#             'duration_ms': 117,
#             'end_time': '2025-10-21 13:09:02.021000000',
#             'events': [],
#             'links': [],
#             'name': 'Sample Trace 3_span_5',
#             'parent_span_id': '',
#             'span_id': 'd13eef3f-0836-4b0c-8abf-5245a7d073d7',
#             'start_time': '2025-10-21 13:09:01.904000000',
#             'status': 'ok',
#             'status_message': '',
#             'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'}],
#  'success': True,
#  'trace_id': '82f70a57-cdac-44ee-9d76-5c14daed1ac4'}
#
# ✓ Found 5 spans

# %% [markdown]
# ## Dataset Methods (15 methods)
#
# Demonstrating all dataset-related API methods.

# %%
# Cell 11: Method 8 - create_dataset()
print("=" * 60)
print("METHOD 8: create_dataset()")
print("=" * 60)
print("\nCreating a new dataset...\n")

dataset = client.create_dataset(
    name=DATASET_NAME,
    slug=DATASET_SLUG,
    description="Demo dataset containing Sample traces for API demonstration",
    visibility="org",
    dataset_type="agent",
    environment=ENVIRONMENT,
    tags=["demo", "Sample", "traces"],
    custom_attributes={
        "source": "sample_traces.json",
        "purpose": "API demonstration"
    }
)

print("✓ Dataset created successfully")
pprint(dataset)
# Out:
# ============================================================
# METHOD 8: create_dataset()
# ============================================================
#
# Creating a new dataset...
#
# ✓ Dataset created successfully
# {'dataset': {'avg_quality_score': 0,
#              'created_at': '2025-10-21 20:32:29.123000000',
#              'created_by': 'system',
#              'current_release': '0.0.0',
#              'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                   'demonstration"}',
#              'dataset_type': 'agent',
#              'description': 'Demo dataset containing Sample traces for API '
#                             'demonstration',
#              'environment': 'development',
#              'id': 'fb640653-ead3-4242-a70d-a92b59686053',
#              'is_active': 1,
#              'items_by_type': '{}',
#              'name': 'Sample Traces Wrapper Demo 8',
#              'next_release': '0.0.1',
#              'organization_id': 'magic-api',
#              'organization_slug': 'magic-api',
#              'project_id': 'default',
#              'slug': 'reddit-traces-wrapper-demo-8',
#              'tags': '["demo","Sample","traces"]',
#              'total_items': '0',
#              'total_size_bytes': '0',
#              'updated_at': '2025-10-21 20:32:29.123000000',
#              'validation_distribution': '{}',
#              'visibility': 'org'},
#  'success': True}

# %%
# Cell 12: Method 9 - list_datasets()
print("=" * 60)
print("METHOD 9: list_datasets()")
print("=" * 60)
print("\nListing all datasets...\n")

datasets_list = client.list_datasets(
    limit=20,
    offset=0,
    visibility="org",
    includeVersions=True
)

pprint(datasets_list)

if "datasets" in datasets_list:
    print(f"\n✓ Found {len(datasets_list['datasets'])} datasets")
# Out:
# ============================================================
# METHOD 9: list_datasets()
# ============================================================
#
# Listing all datasets...
#
# {'datasets': [{'avg_quality_score': 0,
#                'created_at': '2025-09-30 11:55:51.486000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'development',
#                'id': 'be0eaeca-4532-422a-ba8b-69915c373fe5',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Agent Dataset',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'agent',
#                'tags': '[]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-30 11:58:27.024000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'conversational',
#                'description': '',
#                'environment': 'development',
#                'id': '04b20bc4-570a-4601-9c02-11f967a9b057',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Conversational Dataset',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'convo',
#                'tags': '[]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-30 11:59:04.851000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'g-eval',
#                'description': '',
#                'environment': 'development',
#                'id': '77ae798c-6cfb-4974-b0b0-8055e123bc2f',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'G-Eval Datatset',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'mmlu',
#                'tags': '[]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-21 07:46:17.039000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                     'demonstration"}',
#                'dataset_type': 'agent',
#                'description': 'Updated: Demo dataset with Sample traces - now '
#                               'with enhanced metadata',
#                'environment': 'development',
#                'id': 'ce792b79-7621-417b-bd03-09ceb441b609',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Sample Traces Wrapper Demo',
#                'next_release': '0.0.1',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'reddit-traces-wrapper-demo',
#                'tags': '["demo","Sample","traces"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 07:46:27.903000000',
#                'validation_distribution': '{}',
#                'versions': ['0.0.1', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-21 07:49:56.592000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                     'demonstration"}',
#                'dataset_type': 'agent',
#                'description': 'Updated: Demo dataset with Sample traces - now '
#                               'with enhanced metadata',
#                'environment': 'development',
#                'id': '5fdc6d8f-3613-42f5-b436-2838e8143fdd',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Sample Traces Wrapper Demo 2',
#                'next_release': '0.0.1',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'reddit-traces-wrapper-demo-2',
#                'tags': '["demo","Sample","traces"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 07:49:57.735000000',
#                'validation_distribution': '{}',
#                'versions': ['0.0.1', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-21 11:33:00.556000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                     'demonstration"}',
#                'dataset_type': 'agent',
#                'description': 'Updated: Demo dataset with Sample traces - now '
#                               'with enhanced metadata',
#                'environment': 'development',
#                'id': 'b747f038-e5d2-419a-989f-4ee511f4c76b',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Sample Traces Wrapper Demo 5',
#                'next_release': '0.0.1',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'reddit-traces-wrapper-demo-5',
#                'tags': '["demo","Sample","traces"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 11:33:10.886000000',
#                'validation_distribution': '{}',
#                'versions': ['0.0.1', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-21 20:26:04.304000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                     'demonstration"}',
#                'dataset_type': 'agent',
#                'description': 'Updated: Demo dataset with Sample traces - now '
#                               'with enhanced metadata',
#                'environment': 'development',
#                'id': '2d9c1965-7443-4420-be8b-fd66ca2b32e3',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Sample Traces Wrapper Demo 6',
#                'next_release': '0.0.1',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'reddit-traces-wrapper-demo-6',
#                'tags': '["demo","Sample","traces"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 20:26:08.692000000',
#                'validation_distribution': '{}',
#                'versions': ['0.0.1', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-21 20:32:29.123000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                     'demonstration"}',
#                'dataset_type': 'agent',
#                'description': 'Demo dataset containing Sample traces for API '
#                               'demonstration',
#                'environment': 'development',
#                'id': 'fb640653-ead3-4242-a70d-a92b59686053',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Sample Traces Wrapper Demo 8',
#                'next_release': '0.0.1',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'reddit-traces-wrapper-demo-8',
#                'tags': '["demo","Sample","traces"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 20:32:29.123000000',
#                'validation_distribution': '{}',
#                'versions': ['0.0.1', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-24 11:15:02.195000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'custom',
#                'description': '',
#                'environment': 'production',
#                'id': 'ed8012fe-45ec-4b75-9466-910f6a1ce5a3',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'Test Dataset',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': '',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-14 07:02:37.955000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'development',
#                'id': '6dc17a11-5e44-48a5-99f3-21b66fee22fb',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'ai-researcher-demo',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'ai-researcher-demo',
#                'tags': '["ai-agent","research","langchain"]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-13 12:54:53.760000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'custom',
#                'description': '',
#                'environment': 'development',
#                'id': 'c5991260-fce6-4439-b01c-74ad5057751f',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'customer_support_agent_demo',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'customersupportagentdemo',
#                'tags': '[]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-10-13 15:19:42.262000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'production',
#                'id': '31deb11f-58ea-4823-a769-589bba97535a',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'del-this-pls',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'del-this-pls',
#                'tags': '[]',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-25 07:13:39.198000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'production',
#                'id': 'bf5b7344-f3c2-4bb2-8728-a1962cddbe94',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-11',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-11',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.2', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-25 07:16:23.501000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'production',
#                'id': '25709765-aad9-465d-9574-305904539ba9',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-12',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-12',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-25 07:17:50.339000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'production',
#                'id': 'ac55ab9e-9775-4f8d-98bc-ba082c8861aa',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-13',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-13',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-25 07:22:12.158000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'agent',
#                'description': '',
#                'environment': 'production',
#                'id': '2b69edee-4f16-4ac5-916d-8312299d4f14',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-14',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-14',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.2', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-25 07:24:44.954000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'conversational',
#                'description': '',
#                'environment': 'production',
#                'id': '70f52b46-ddab-4282-991c-66be0a39bc29',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-15',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-15',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.2', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-24 11:38:11.875000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'custom',
#                'description': '',
#                'environment': 'production',
#                'id': '028f864f-f589-458a-8f77-fd92b093ab48',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-2',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-2',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.2', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-24 11:48:21.236000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'custom',
#                'description': '',
#                'environment': 'production',
#                'id': '8fb280a8-cb21-4931-8ef7-62b3fca5190e',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-3',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-3',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.0'],
#                'visibility': 'org'},
#               {'avg_quality_score': 0,
#                'created_at': '2025-09-24 11:48:54.362000000',
#                'created_by': 'system',
#                'current_release': '0.0.0',
#                'custom_attributes': '{}',
#                'dataset_type': 'custom',
#                'description': '',
#                'environment': 'production',
#                'id': 'c653e146-1e85-4e5b-bdd4-09ea690faa7d',
#                'is_active': 1,
#                'items_by_type': '{}',
#                'name': 'demo-fail-4',
#                'next_release': '1.0.0',
#                'organization_id': 'magic-api',
#                'organization_slug': 'magic-api',
#                'project_id': 'default',
#                'slug': 'demo-fail-4',
#                'tags': '{}',
#                'total_items': '0',
#                'total_size_bytes': '0',
#                'updated_at': '2025-10-21 05:21:15.020000000',
#                'validation_distribution': '{}',
#                'versions': ['1.0.0', '0.0.2', '0.0.0'],
#                'visibility': 'org'}],
#  'limit': 20,
#  'offset': 0,
#  'success': True,
#  'total': 34}
#
# ✓ Found 20 datasets

# %%
# Cell 13: Method 10 - get_dataset()
print("=" * 60)
print("METHOD 10: get_dataset()")
print("=" * 60)
print(f"\nFetching dataset by slug: {DATASET_SLUG}\n")

dataset_detail = client.get_dataset(DATASET_SLUG)
pprint(dataset_detail)
# Out:
# ============================================================
# METHOD 10: get_dataset()
# ============================================================
#
# Fetching dataset by slug: reddit-traces-wrapper-demo-8
#
# {'dataset': {'avg_quality_score': 0,
#              'created_at': '2025-10-21 20:32:29.123000000',
#              'created_by': 'system',
#              'current_release': '0.0.0',
#              'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                   'demonstration"}',
#              'dataset_type': 'agent',
#              'description': 'Demo dataset containing Sample traces for API '
#                             'demonstration',
#              'environment': 'development',
#              'id': 'fb640653-ead3-4242-a70d-a92b59686053',
#              'is_active': 1,
#              'items_by_type': '{}',
#              'name': 'Sample Traces Wrapper Demo 8',
#              'next_release': '0.0.1',
#              'organization_id': 'magic-api',
#              'organization_slug': 'magic-api',
#              'project_id': 'default',
#              'slug': 'reddit-traces-wrapper-demo-8',
#              'tags': '["demo","Sample","traces"]',
#              'total_items': '0',
#              'total_size_bytes': '0',
#              'updated_at': '2025-10-21 20:32:29.123000000',
#              'validation_distribution': '{}',
#              'visibility': 'org'},
#  'success': True}

# %%
# Cell 14: Method 11 - update_dataset()
print("=" * 60)
print("METHOD 11: update_dataset()")
print("=" * 60)
print(f"\nUpdating dataset: {DATASET_SLUG}\n")

updated_dataset = client.update_dataset(
    slug=DATASET_SLUG,
    description="Updated: Demo dataset with Sample traces - now with enhanced metadata",
    tags=["demo", "Sample", "traces", "updated"],
    custom_attributes={
        "source": "sample_traces.json",
        "purpose": "API demonstration",
        "updated": True,
        "version_info": "Enhanced with additional metadata"
    }
)

print("✓ Dataset updated successfully")
pprint(updated_dataset)
# Out:
# ============================================================
# METHOD 11: update_dataset()
# ============================================================
#
# Updating dataset: reddit-traces-wrapper-demo-8
#
# ✓ Dataset updated successfully
# {'dataset': {'avg_quality_score': 0,
#              'created_at': '2025-10-21 20:32:29.123000000',
#              'created_by': 'system',
#              'current_release': '0.0.0',
#              'custom_attributes': '{"source":"sample_traces.json","purpose":"API '
#                                   'demonstration"}',
#              'dataset_type': 'agent',
#              'description': 'Updated: Demo dataset with Sample traces - now '
#                             'with enhanced metadata',
#              'environment': 'development',
#              'id': 'fb640653-ead3-4242-a70d-a92b59686053',
#              'is_active': 1,
#              'items_by_type': '{}',
#              'name': 'Sample Traces Wrapper Demo 8',
#              'next_release': '0.0.1',
#              'organization_id': 'magic-api',
#              'organization_slug': 'magic-api',
#              'project_id': 'default',
#              'slug': 'reddit-traces-wrapper-demo-8',
#              'tags': '["demo","Sample","traces"]',
#              'total_items': '0',
#              'total_size_bytes': '0',
#              'updated_at': '2025-10-21 20:32:30.210000000',
#              'validation_distribution': '{}',
#              'visibility': 'org'},
#  'success': True}

# %%
# Cell 15: Method 12 - create_dataset_version()
print("=" * 60)
print("METHOD 12: create_dataset_version()")
print("=" * 60)
print(f"\nCreating version {DATASET_VERSION} for dataset: {DATASET_SLUG}\n")

version_data = {
    "version": DATASET_VERSION,
    "description": "Initial version with 10 Sample trace samples",
    "tags": ["v1", "initial"],
    "custom_attributes": {
        "trace_count": NUM_TRACES,
        "created_by": "demo_script"
    }
}

version = client.create_dataset_version(DATASET_SLUG, version_data)
print(f"✓ Version {DATASET_VERSION} created successfully")
pprint(version)
# Out:
# ============================================================
# METHOD 12: create_dataset_version()
# ============================================================
#
# Creating version 1.0.0 for dataset: reddit-traces-wrapper-demo-8
#
# ✓ Version 1.0.0 created successfully
# {'success': True, 'version': '1.0.0'}

# %%
# Cell 16: Method 13 - list_dataset_versions()
print("=" * 60)
print("METHOD 13: list_dataset_versions()")
print("=" * 60)
print(f"\nListing all versions for dataset: {DATASET_SLUG}\n")

versions_list = client.list_dataset_versions(DATASET_SLUG)
pprint(versions_list)

if "versions" in versions_list:
    print(f"\n✓ Found {len(versions_list['versions'])} versions")
# Out:
# ============================================================
# METHOD 13: list_dataset_versions()
# ============================================================
#
# Listing all versions for dataset: reddit-traces-wrapper-demo-8
#
# {'current_release': '0.0.0',
#  'next_release': '0.0.1',
#  'success': True,
#  'versions': ['0.0.1', '0.0.0']}
#
# ✓ Found 2 versions

# %%
# Cell 17: Method 14 - get_dataset_version()
print("=" * 60)
print("METHOD 14: get_dataset_version()")
print("=" * 60)
print(f"\nFetching version {DATASET_VERSION} for dataset: {DATASET_SLUG}\n")

version_detail = client.get_dataset_version(DATASET_SLUG, DATASET_VERSION)
pprint(version_detail)
# Out:
# ============================================================
# METHOD 14: get_dataset_version()
# ============================================================
#
# Fetching version 1.0.0 for dataset: reddit-traces-wrapper-demo-8
#
# {'current_release': '0.0.0',
#  'exists': False,
#  'is_current_release': False,
#  'is_next_release': False,
#  'item_count': 0,
#  'next_release': '0.0.1',
#  'status': 'nonexistent',
#  'success': True,
#  'version': '1.0.0'}

# %%
# Cell 17a: Method 15 - get_dataset_versions_diff()
print("=" * 60)
print("METHOD 15: get_dataset_versions_diff()")
print("=" * 60)
print(f"\nGetting diff between current_release and next_release for: {DATASET_SLUG}\n")

versions_diff = client.get_dataset_versions_diff(DATASET_SLUG)
pprint(versions_diff)

print("\n✓ Version diff retrieved successfully")
print("This shows changes between current_release and next_release versions")
# Out:
# ============================================================
# METHOD 15: get_dataset_versions_diff()
# ============================================================
#
# Getting diff between current_release and next_release for: reddit-traces-wrapper-demo-8
#
# {'changes': {'added': [], 'deleted': [], 'modified': []},
#  'current_release': '0.0.0',
#  'current_release_count': 0,
#  'next_release': '0.0.1',
#  'next_release_count': 0,
#  'success': True,
#  'summary': {'added': 0, 'deleted': 0, 'modified': 0, 'total_changes': 0}}
#
# ✓ Version diff retrieved successfully
# This shows changes between current_release and next_release versions

# %%
# Cell 18: Transform traces into dataset items
print("=" * 60)
print("PREPARING DATASET ITEMS")
print("=" * 60)
print("\nTransforming traces into dataset item format...\n")

dataset_items = []
for i, trace in enumerate(traces_sample):
    item = {
        "item_key": f"trace_{i+1:03d}",
        "item_type": "agent_trace",
        "content": {
            "trace_id": trace.get("trace_id"),
            "span_id": trace.get("span_id"),
            "name": trace.get("name"),
            "start_time": trace.get("start_time"),
            "end_time": trace.get("end_time"),
            "duration_ms": trace.get("duration_ms"),
            "status": trace.get("status"),
            "attributes": trace.get("attributes", {})
        },
        "metadata": {
            "project": trace.get("project", PROJECT_NAME),
            "environment": trace.get("environment", ENVIRONMENT),
            "item_index": i + 1
        }
    }
    dataset_items.append(item)

print(f"✓ Prepared {len(dataset_items)} dataset items")
print("\nSample item structure:")
pprint(dataset_items[0])
# Out:
# ============================================================
# PREPARING DATASET ITEMS
# ============================================================
#
# Transforming traces into dataset item format...
#
# ✓ Prepared 10 dataset items
#
# Sample item structure:
# {'content': {'attributes': {},
#              'duration_ms': 556,
#              'end_time': '2025-10-21T13:09:01.736210Z',
#              'name': 'Sample Trace 1',
#              'span_id': None,
#              'start_time': '2025-10-21T13:09:01.180210Z',
#              'status': 'ok',
#              'trace_id': 'e5eebd9b-3f9e-463f-b8f3-96e20a1f771a'},
#  'item_key': 'trace_001',
#  'item_type': 'agent_trace',
#  'metadata': {'environment': 'development',
#               'item_index': 1,
#               'project': 'noveum-api-wrapper-demo'}}

# %%
# Cell 19: Method 16 - add_dataset_items()
print("=" * 60)
print("METHOD 16: add_dataset_items()")
print("=" * 60)
print(f"\nAdding {len(dataset_items)} items to dataset: {DATASET_SLUG}\n")
print("Note: Items are automatically added to the 'next_release' version\n")

add_items_result = client.add_dataset_items(
    dataset_slug=DATASET_SLUG,
    items=dataset_items
)

print(f"✓ Successfully added {len(dataset_items)} items")
pprint(add_items_result)
# Out:
# ============================================================
# METHOD 16: add_dataset_items()
# ============================================================
#
# Adding 10 items to dataset: reddit-traces-wrapper-demo-8
#
# Note: Items are automatically added to the 'next_release' version
#
# ✓ Successfully added 10 items
# {'created': 10, 'success': True}

# %%
# Cell 22: Method 19 - publish_dataset_version()
print("=" * 60)
print("METHOD 19: publish_dataset_version()")
print("=" * 60)

print(f"\nPublishing next_release version for dataset: {DATASET_SLUG}\n")
print("Note: Automatically publishes 'next_release' and increments version number\n")

publish_result = client.publish_dataset_version(DATASET_SLUG)
print("✓ Version published successfully")
pprint(publish_result)
# Out:
# ============================================================
# METHOD 19: publish_dataset_version()
# ============================================================
#
# Publishing next_release version for dataset: reddit-traces-wrapper-demo-8
#
# Note: Automatically publishes 'next_release' and increments version number
#
# ✓ Version published successfully
# {'current_release': '0.0.1', 'next_release': '0.0.2', 'success': True}

# %%
# Cell 20: Method 17 - list_dataset_items()
print("=" * 60)
print("METHOD 17: list_dataset_items()")
print("=" * 60)
print(f"\nListing items from dataset: {DATASET_SLUG}\n")
print("Note: New optional parameters available: item_type, search, sort_by, sort_order\n")

items_list = client.list_dataset_items(
    dataset_slug=DATASET_SLUG,
    limit=20,
    offset=0
)

pprint(items_list)

if "items" in items_list:
    print(f"\n✓ Found {len(items_list['items'])} items")
    # Store first item key for later use
    if len(items_list["items"]) > 0:
        sample_item_key = items_list["items"][0].get("item_key", "trace_001")
        sample_item_id = items_list["items"][0].get("id", items_list["items"][0].get("item_key", "trace_001"))
        print(f"  Sample item key: {sample_item_key}")
        print(f"  Sample item ID: {sample_item_id}")
else:
    sample_item_key = "trace_001"
    sample_item_id = "trace_001"
# Out:
# ============================================================
# METHOD 17: list_dataset_items()
# ============================================================
#
# Listing items from dataset: reddit-traces-wrapper-demo-8
#
# Note: New optional parameters available: item_type, search, sort_by, sort_order
#
# {'items': [{'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': 'f1716d691f365bf2a809da43ac336afa28767fc7a7112e303d6075e9a21bd839',
#             'item_id': '7833bb3e-6f00-4ac4-88e8-76651681208c',
#             'item_key': 'trace_001',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":1}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': 'ebfffc1d6674cb101f2e81a283f6ddf6bb78d5f2579d47e0ed0017bffbf73098',
#             'item_id': '0907dad7-e9a0-4a91-8301-176364cb0763',
#             'item_key': 'trace_002',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":2}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '5129a3649831cde7247f721cfcab752e36a5fb6c068ec0f2a15435edd35290a5',
#             'item_id': '23515bdb-7178-4987-8bde-db9d282af3bc',
#             'item_key': 'trace_003',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":3}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '4f6df22c01a043ae786479b7881605dd521c35861d8c089f77f93e51e0a023e8',
#             'item_id': '374332d3-fa22-44ff-9fde-20d27cf2bb64',
#             'item_key': 'trace_004',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":4}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': 'e59ca90f9c35112b9860d4ad6351d42f44aafee64610c1f0a541500422f84445',
#             'item_id': 'fd0d89d9-cb0d-4a00-906e-3f178d540bdb',
#             'item_key': 'trace_005',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":5}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '2c48bd822cc0fbec213c528035ba29b5e0f6bc86f8f2ffe298a8582fcc22a042',
#             'item_id': 'e0c6b8a4-59f7-4e0f-a20c-47e97bde210e',
#             'item_key': 'trace_006',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":6}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': 'f542541e8f9fc0402c5eace45f9a35290778a3c9a07aca13f909d61f3d9c8cd7',
#             'item_id': '9727c878-324b-48db-9ce8-8a49ebe2254c',
#             'item_key': 'trace_007',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":7}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '3bee513b83b8c45723c758cdcc1eea82a7db6adeb9d3e22a9ed1dc16feb5a2cf',
#             'item_id': '6cd171b6-46ec-48a9-92c7-1681199a9dc6',
#             'item_key': 'trace_008',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":8}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '0ad0362b6ab6d6127df728209f1cbe010ec3c8c7a12cbd436b554dbd4de55048',
#             'item_id': '8bd1720c-29b4-4970-b6dc-15ead7fb150f',
#             'item_key': 'trace_009',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":9}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''},
#            {'agent_exit': '',
#             'agent_name': '',
#             'agent_response': '',
#             'agent_role': '',
#             'agent_task': '',
#             'content': '',
#             'conversation_context': '{}',
#             'conversation_id': '',
#             'created_at': '2025-10-21 20:32:31.677000000',
#             'criteria': '',
#             'custom_attributes': '{}',
#             'dataset_id': 'fb640653-ead3-4242-a70d-a92b59686053',
#             'dataset_slug': 'reddit-traces-wrapper-demo-8',
#             'deleted_at_date': '1970-01-01 00:00:00.000000000',
#             'deleted_at_version': '',
#             'evaluation_context': '{}',
#             'exit_status': '',
#             'expected_output': '',
#             'expected_tool_call': '',
#             'ground_truth': '',
#             'input_text': '',
#             'item_hash': '9a6565e86220c9a3ab736bd95fec7de3a00ec4549f5e438663954605c5423a3e',
#             'item_id': 'f839e4bc-70cf-45b9-bd06-66fd20a5bccd',
#             'item_key': 'trace_010',
#             'item_type': 'agent_trace',
#             'item_version': '0.0.1',
#             'message': '',
#             'metadata': '{"project":"noveum-api-wrapper-demo","environment":"development","item_index":10}',
#             'organization_id': 'magic-api',
#             'organization_slug': 'magic-api',
#             'output_text': '',
#             'parameters_passed': '{}',
#             'quality_score': 0,
#             'retrieval_query': '[]',
#             'retrieved_context': '[]',
#             'schema_version': '1.0.0',
#             'scorer_results': [],
#             'session_id': '',
#             'source_span_id': '',
#             'source_trace_id': '',
#             'speaker': '',
#             'system_prompt': '',
#             'tags': '{}',
#             'tool_call_results': '[]',
#             'tool_calls': '[]',
#             'tools_available': '[]',
#             'trace_data': '{}',
#             'turn_id': '',
#             'updated_at': '2025-10-21 20:32:31.677000000',
#             'user_id': '',
#             'validation_errors': '[]',
#             'validation_status': ''}],
#  'success': True,
#  'total': 10}
#
# ✓ Found 10 items
#   Sample item key: trace_001
#   Sample item ID: trace_001

# %%
# # Cell 21: Method 18 - get_dataset_item() currently doesnt work
# print("=" * 60)
# print("METHOD 18: get_dataset_item()")
# print("=" * 60)
# print(f"\nFetching specific item: {sample_item_key}\n")

# item_detail = client.get_dataset_item(DATASET_SLUG, sample_item_key)
# pprint(item_detail)
# Out:
# ============================================================
# METHOD 18: get_dataset_item()
# ============================================================
#
# Fetching specific item: trace_001
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[61], line 7
#       4 print("=" * 60)
#       5 print(f"\nFetching specific item: {sample_item_key}\n")
# ----> 7 item_detail = client.get_dataset_item(DATASET_SLUG, sample_item_key)
#       8 pprint(item_detail)
#
# File ~/Desktop/noveum/NovaEval/src/novaeval/noveum_platform/client.py:879, in NoveumClient.get_dataset_item(self, dataset_slug, item_key)
#     872 logger.info("Getting item %s from dataset %s", item_key, dataset_slug)
#     874 response = self.session.get(
#     875     f"{self.base_url}/api/v1/datasets/{dataset_slug}/items/{item_key}",
#     876     timeout=self.timeout,
#     877 )
# --> 879 return self._handle_response(response)
#
# File ~/Desktop/noveum/NovaEval/src/novaeval/noveum_platform/client.py:135, in NoveumClient._handle_response(self, response)
#     128     raise ForbiddenError(
#     129         message=response_body.get(
#     130             "message", "Forbidden (org mismatch or access denied)"
#     131         ),
#     132         response_body=response_body,
#     133     )
#     134 elif response.status_code == 404:
# --> 135     raise NotFoundError(
#     136         message=response_body.get("message", "Resource not found"),
#     137         response_body=response_body,
#     138     )
#     139 elif response.status_code == 409:
#     140     raise ConflictError(
#     141         message=response_body.get("message", "Conflict - Trace is immutable"),
#     142         response_body=response_body,
#     143     )
#
# NotFoundError: Resource not found (HTTP 404)

# %%
# Cell 23: Method 20 - delete_dataset_item()
print("=" * 60)
print("METHOD 20: delete_dataset_item()")
print("=" * 60)
print(f"\nDeleting specific item: {sample_item_id}\n")

delete_item_result = client.delete_dataset_item(DATASET_SLUG, sample_item_id)
print(f"✓ Item {sample_item_id} deleted successfully")
pprint(delete_item_result)
# Out:
# ============================================================
# METHOD 20: delete_dataset_item()
# ============================================================
#
# Deleting specific item: trace_001
#
# ✓ Item trace_001 deleted successfully
# {'success': True}

# %%
# Cell 24: Method 21 - delete_all_dataset_items() - Demo only
print("=" * 60)
print("METHOD 21: delete_all_dataset_items()")
print("=" * 60)
print("Demonstrating delete_all_dataset_items()...")

# Note: This method requires specific item IDs to delete
# For demo purposes, we will use some example item IDs
example_item_ids = ["item-1", "item-2", "item-3"]
print(f"Attempting to delete items: {example_item_ids}")

try:
    delete_result = client.delete_all_dataset_items(DATASET_SLUG, example_item_ids)
    print(f"✓ Deletion result: {delete_result}")
except Exception as e:
    print(f"⚠ Deletion failed (expected if items do not exist): {type(e).__name__}: {e}")

print("\nNote: delete_all_dataset_items() requires item_ids as second parameter (required)")
print("The method will throw ValidationError if no item_ids are provided")
# Out:
# ============================================================
# METHOD 21: delete_all_dataset_items()
# ============================================================
# Demonstrating delete_all_dataset_items()...
# Attempting to delete items: ['item-1', 'item-2', 'item-3']
# ✓ Deletion result: {'success': True, 'deleted': 3}
#
# Note: delete_all_dataset_items() requires item_ids as second parameter (required)
# The method will throw ValidationError if no item_ids are provided

# %% [markdown]
# ## Scorer Results Methods (6 methods)
#
# Demonstrating all scorer results-related API methods.

# %%
# Cell 25
# Re-add items for scorer demo
add_items_result = client.add_dataset_items(
    dataset_slug=DATASET_SLUG,
    items=dataset_items
)
print(f"✓ Re-added {len(dataset_items)} items for scorer results demo")
# Out:
# ✓ Re-added 10 items for scorer results demo

# %%
# Cell 26: Method 22 - create_scorer_result()
print("=" * 60)
print("METHOD 22: create_scorer_result()")
print("=" * 60)
print("\nCreating a single scorer result...\n")

# Get first item for scoring
items_list = client.list_dataset_items(DATASET_SLUG, version="0.0.1", limit=1)
first_item_id = items_list["items"][0].get("id", items_list["items"][0].get("item_key", "trace_001"))

scorer_result_data = {
    "datasetSlug": DATASET_SLUG,
    "itemId": first_item_id,
    "scorerId": SCORER_ID,
    "score": 0.95,
    "metadata": {
        "confidence": 0.92,
        "model": "demo-scorer-v1"
    },
    "details": {
        "quality_aspects": {
            "completeness": 0.98,
            "accuracy": 0.94,
            "relevance": 0.93
        }
    }
}

scorer_result = client.create_scorer_result(scorer_result_data, organizationSlug=ORGANIZATION_SLUG)
print("✓ Scorer result created successfully")
pprint(scorer_result)
# Out:
# ============================================================
# METHOD 22: create_scorer_result()
# ============================================================
#
# Creating a single scorer result...
#
# ✓ Scorer result created successfully
# {'created_at': '2025-10-21 20:27:35.091000000',
#  'dataset_slug': 'reddit-traces-wrapper-demo-7',
#  'error': '',
#  'execution_time_ms': 0,
#  'item_id': 'trace_001',
#  'metadata': '{"confidence":0.92,"model":"demo-scorer-v1"}',
#  'organization_slug': 'magic-api',
#  'passed': 0,
#  'result_id': '79d55b9e-b201-4b69-a730-1ad48f73e7b0',
#  'score': 0.95,
#  'scorer_id': 'demo-quality-scorer',
#  'scorer_name': 'Unknown Scorer',
#  'updated_at': '2025-10-21 20:27:35.091000000'}

# %%
# Cell 27: Method 23 - create_scorer_results_batch()
print("=" * 60)
print("METHOD 23: create_scorer_results_batch()")
print("=" * 60)
print("\nCreating scorer results in batch...\n")

# Get all items for batch scoring
items_list = client.list_dataset_items(DATASET_SLUG, version="0.0.1", limit=50)

batch_results = []
for i, item in enumerate(items_list["items"]):
    item_id = item.get("id", item.get("item_key"))
    # Create varied scores for demonstration
    score = 0.75 + (i * 0.02)  # Scores from 0.75 to 0.93
    if score > 1.0:
        score = 0.95

    result = {
        "datasetSlug": DATASET_SLUG,
        "itemId": item_id,
        "scorerId": f"{SCORER_ID}-batch",
        "score": round(score, 2),
        "metadata": {
            "batch_index": i,
            "processing_time_ms": 120 + (i * 10)
        }
    }
    batch_results.append(result)

batch_create_result = client.create_scorer_results_batch(batch_results, organizationSlug=ORGANIZATION_SLUG)
print(f"✓ Created {len(batch_results)} scorer results in batch")
pprint(batch_create_result)
# Out:
# ============================================================
# METHOD 23: create_scorer_results_batch()
# ============================================================
#
# Creating scorer results in batch...
#
# ✓ Created 10 scorer results in batch
# {'created': 10,
#  'failed': 0,
#  'results': [{'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_001',
#               'metadata': '{"batch_index":0,"processing_time_ms":120}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '86a0f128-fc89-44a7-b5fc-5c7d44afe71f',
#               'score': 0.75,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_002',
#               'metadata': '{"batch_index":1,"processing_time_ms":130}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'e417fcaa-bfed-4871-b50c-504e5f8b6624',
#               'score': 0.77,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_003',
#               'metadata': '{"batch_index":2,"processing_time_ms":140}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '72f0fa00-c25f-411a-b010-1e4223f03886',
#               'score': 0.79,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_004',
#               'metadata': '{"batch_index":3,"processing_time_ms":150}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '7f190f10-a42e-4aef-82c7-f23f821f80ba',
#               'score': 0.81,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_005',
#               'metadata': '{"batch_index":4,"processing_time_ms":160}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '4cd3b5a3-18ad-439d-aa34-cf51b017372c',
#               'score': 0.83,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_006',
#               'metadata': '{"batch_index":5,"processing_time_ms":170}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'e9c66db6-57bb-4316-bc28-d4c37c5c9f10',
#               'score': 0.85,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_007',
#               'metadata': '{"batch_index":6,"processing_time_ms":180}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'a76056c1-c611-4291-8a31-00a7de1eeadb',
#               'score': 0.87,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_008',
#               'metadata': '{"batch_index":7,"processing_time_ms":190}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'ec0f5607-b055-490e-b241-9f47971fb881',
#               'score': 0.89,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_009',
#               'metadata': '{"batch_index":8,"processing_time_ms":200}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '29e54f00-5517-4ac4-a68a-e136bf939264',
#               'score': 0.91,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_010',
#               'metadata': '{"batch_index":9,"processing_time_ms":210}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '108c7e0f-aaa6-420c-95fe-621f9e22fb75',
#               'score': 0.93,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'}],
#  'success': True}

# %%
# Cell 28: Method 24 - list_scorer_results()
print("=" * 60)
print("METHOD 24: list_scorer_results()")
print("=" * 60)
print("\nListing scorer results...\n")

scorer_results_list = client.list_scorer_results(
    organizationSlug=ORGANIZATION_SLUG,
    datasetSlug=DATASET_SLUG,
    limit=100,
    offset=0
)

pprint(scorer_results_list)

if "results" in scorer_results_list:
    print(f"\n✓ Found {len(scorer_results_list['results'])} scorer results")
# Out:
# ============================================================
# METHOD 24: list_scorer_results()
# ============================================================
#
# Listing scorer results...
#
# {'results': [{'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_001',
#               'metadata': '{"batch_index":0,"processing_time_ms":120}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '86a0f128-fc89-44a7-b5fc-5c7d44afe71f',
#               'score': 0.75,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_002',
#               'metadata': '{"batch_index":1,"processing_time_ms":130}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'e417fcaa-bfed-4871-b50c-504e5f8b6624',
#               'score': 0.77,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_003',
#               'metadata': '{"batch_index":2,"processing_time_ms":140}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '72f0fa00-c25f-411a-b010-1e4223f03886',
#               'score': 0.79,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_004',
#               'metadata': '{"batch_index":3,"processing_time_ms":150}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '7f190f10-a42e-4aef-82c7-f23f821f80ba',
#               'score': 0.81,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_005',
#               'metadata': '{"batch_index":4,"processing_time_ms":160}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '4cd3b5a3-18ad-439d-aa34-cf51b017372c',
#               'score': 0.83,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_006',
#               'metadata': '{"batch_index":5,"processing_time_ms":170}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'e9c66db6-57bb-4316-bc28-d4c37c5c9f10',
#               'score': 0.85,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_007',
#               'metadata': '{"batch_index":6,"processing_time_ms":180}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'a76056c1-c611-4291-8a31-00a7de1eeadb',
#               'score': 0.87,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_008',
#               'metadata': '{"batch_index":7,"processing_time_ms":190}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': 'ec0f5607-b055-490e-b241-9f47971fb881',
#               'score': 0.89,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_009',
#               'metadata': '{"batch_index":8,"processing_time_ms":200}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '29e54f00-5517-4ac4-a68a-e136bf939264',
#               'score': 0.91,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:37.138000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_010',
#               'metadata': '{"batch_index":9,"processing_time_ms":210}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '108c7e0f-aaa6-420c-95fe-621f9e22fb75',
#               'score': 0.93,
#               'scorer_id': 'demo-quality-scorer-batch',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:37.138000000'},
#              {'created_at': '2025-10-21 20:27:35.091000000',
#               'dataset_slug': 'reddit-traces-wrapper-demo-7',
#               'error': '',
#               'execution_time_ms': 0,
#               'item_id': 'trace_001',
#               'metadata': '{"confidence":0.92,"model":"demo-scorer-v1"}',
#               'organization_slug': 'magic-api',
#               'passed': 0,
#               'result_id': '79d55b9e-b201-4b69-a730-1ad48f73e7b0',
#               'score': 0.95,
#               'scorer_id': 'demo-quality-scorer',
#               'scorer_name': 'Unknown Scorer',
#               'updated_at': '2025-10-21 20:27:35.091000000'}]}
#
# ✓ Found 11 scorer results

# %%
# Cell 29: Method 25 - get_scorer_result()
print("=" * 60)
print("METHOD 25: get_scorer_result()")
print("=" * 60)
print("\nFetching specific scorer result...\n")

scorer_result_detail = client.get_scorer_result(
    dataset_slug=DATASET_SLUG,
    item_id=first_item_id,
    scorer_id=SCORER_ID,
    organizationSlug=ORGANIZATION_SLUG
)

pprint(scorer_result_detail)
# Out:
# ============================================================
# METHOD 25: get_scorer_result()
# ============================================================
#
# Fetching specific scorer result...
#
# {'created_at': '2025-10-21 20:27:35.091000000',
#  'dataset_slug': 'reddit-traces-wrapper-demo-7',
#  'error': '',
#  'execution_time_ms': 0,
#  'item_id': 'trace_001',
#  'metadata': '{"confidence":0.92,"model":"demo-scorer-v1"}',
#  'organization_slug': 'magic-api',
#  'passed': 0,
#  'result_id': '79d55b9e-b201-4b69-a730-1ad48f73e7b0',
#  'score': 0.95,
#  'scorer_id': 'demo-quality-scorer',
#  'scorer_name': 'Unknown Scorer',
#  'updated_at': '2025-10-21 20:27:35.091000000'}

# %%
# Cell 30: Method 26 - update_scorer_result()
print("=" * 60)
print("METHOD 26: update_scorer_result()")
print("=" * 60)
print("\nUpdating scorer result...\n")

update_data = {
    "score": 0.98,
    "metadata": {
        "confidence": 0.97,
        "model": "demo-scorer-v2",
        "updated": True
    },
    "details": {
        "quality_aspects": {
            "completeness": 0.99,
            "accuracy": 0.98,
            "relevance": 0.97
        },
        "improvement": "Enhanced scoring algorithm applied"
    }
}

updated_scorer_result = client.update_scorer_result(
    dataset_slug=DATASET_SLUG,
    item_id=first_item_id,
    scorer_id=SCORER_ID,
    result_data=update_data,
    organizationSlug=ORGANIZATION_SLUG
)

print("✓ Scorer result updated successfully")
pprint(updated_scorer_result)
# Out:
# ============================================================
# METHOD 26: update_scorer_result()
# ============================================================
#
# Updating scorer result...
#
# ✓ Scorer result updated successfully
# {'created_at': '2025-10-21 20:27:35.091000000',
#  'dataset_slug': 'reddit-traces-wrapper-demo-7',
#  'error': '',
#  'execution_time_ms': 0,
#  'item_id': 'trace_001',
#  'metadata': '{"confidence":0.97,"model":"demo-scorer-v2","updated":true}',
#  'organization_slug': 'magic-api',
#  'passed': 0,
#  'result_id': '79d55b9e-b201-4b69-a730-1ad48f73e7b0',
#  'score': 0.98,
#  'scorer_id': 'demo-quality-scorer',
#  'scorer_name': 'Unknown Scorer',
#  'updated_at': '2025-10-21 20:27:42.679000000'}

# %%
# Cell 31: Method 27 - delete_scorer_result()
print("=" * 60)
print("METHOD 27: delete_scorer_result()")
print("=" * 60)
print("\nDeleting specific scorer result...\n")

delete_scorer_result = client.delete_scorer_result(
    dataset_slug=DATASET_SLUG,
    item_id=first_item_id,
    scorer_id=SCORER_ID,
    organizationSlug=ORGANIZATION_SLUG
)

print("✓ Scorer result deleted successfully")
pprint(delete_scorer_result)
# Out:
# ============================================================
# METHOD 27: delete_scorer_result()
# ============================================================
#
# Deleting specific scorer result...
#
# ✓ Scorer result deleted successfully
# {}

# %% [markdown]
# ## Cleanup

# %%
# Cell 32: Method 28 - delete_dataset()
print("=" * 60)
print("METHOD 28: delete_dataset()")
print("=" * 60)
print(f"\nDeleting dataset: {DATASET_SLUG}\n")

delete_dataset_result = client.delete_dataset(DATASET_SLUG)
print(f"✓ Dataset {DATASET_SLUG} deleted successfully")
pprint(delete_dataset_result)
# Out:
# ============================================================
# METHOD 28: delete_dataset()
# ============================================================
#
# Deleting dataset: reddit-traces-wrapper-demo-7
#
# ✓ Dataset reddit-traces-wrapper-demo-7 deleted successfully
# {'success': True}

# %% [markdown]
# ## Summary
#
# ### Congratulations! 🎉
#
# You have successfully demonstrated all **28 methods** of the Noveum Platform API Client!
#
# #### Methods Demonstrated:
#
# **Trace Methods (7)**
# 1. `get_connection_status()` - Check API connection
# 2. `get_directory_tree()` - Get organization structure
# 3. `ingest_trace()` - Ingest single trace
# 4. `ingest_traces()` - Batch ingest traces
# 5. `query_traces()` - Query traces with filters
# 6. `get_trace()` - Get specific trace
# 7. `get_trace_spans()` - Get trace spans
#
# **Dataset Methods (15)**
# 8. `create_dataset()` - Create new dataset
# 9. `list_datasets()` - List all datasets
# 10. `get_dataset()` - Get specific dataset
# 11. `update_dataset()` - Update dataset metadata
# 12. `create_dataset_version()` - Create dataset version
# 13. `list_dataset_versions()` - List dataset versions
# 14. `get_dataset_version()` - Get specific version
# 15. `get_dataset_versions_diff()` - Get diff between current and next release
# 16. `add_dataset_items()` - Add items to dataset
# 17. `list_dataset_items()` - List dataset items
# 18. `get_dataset_item()` - Get specific item
# 19. `publish_dataset_version()` - Publish version
# 20. `delete_dataset_item()` - Delete specific item
# 21. `delete_all_dataset_items()` - Delete all items
# 22. `delete_dataset()` - Delete dataset
#
# **Scorer Results Methods (6)**
# 23. `create_scorer_result()` - Create single result
# 24. `create_scorer_results_batch()` - Batch create results
# 25. `list_scorer_results()` - List scorer results
# 26. `get_scorer_result()` - Get specific result
# 27. `update_scorer_result()` - Update result
# 28. `delete_scorer_result()` - Delete result
#
# ### Next Steps
# - Customize the configuration variables at the top to use with your own data
# - Explore different filter options in query methods
# - Integrate these methods into your own workflows
# - Check the [API documentation](../src/novaeval/noveum_platform/README.md) for more details
